# %%
import numpy as np

print(np.__version__)
# Out:
# 1.26.4

# %%
import numpy as np
import pandas as pd
import torch
print("All set! PyTorch version:", torch.__version__)
# Out:
# All set! PyTorch version: 2.10.0+cpu
